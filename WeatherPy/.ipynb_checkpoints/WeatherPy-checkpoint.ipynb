# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
from datetime import datetime

# Import API key
from api_keys import api_key
from pprint import pprint

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
city_stats = {}

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        city_stats[city] = {"Lat":lat_lng[0], "Long":lat_lng[1]}

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 612

# %%
#Print cities with coordinates
pprint(city_stats)
# Out:
# {'abu dhabi': {'Lat': 21.259823710945483, 'Long': 53.132564203592835},
#  'adaufe': {'Lat': 41.59504410934849, 'Long': -8.395476605795949},
#  'aden': {'Lat': 12.189945355237725, 'Long': 45.07374472699044},
#  'adrar': {'Lat': 28.89302391766195, 'Long': -1.8385517015174457},
#  'aflu': {'Lat': 34.053742952242814, 'Long': 0.7303033432764323},
#  'agadir': {'Lat': 30.010245926211653, 'Long': -9.404575527877967},
#  'agra': {'Lat': 27.141136624893107, 'Long': 78.09229906313345},
#  'ahipara': {'Lat': -30.591025576934, 'Long': 168.18970340751338},
#  'ahmadnagar': {'Lat': 19.099816666172913, 'Long': 74.72793218039149},
#  'ahuimanu': {'Lat': 38.22141253766128, 'Long': -151.5281091358945},
#  'ahumada': {'Lat': 30.78105161968992, 'Long': -106.02700065306145},
#  'airai': {'Lat': 5.619502039528172, 'Long': 139.19424879669384},
#  'aitape': {'Lat': -1.837578978247251, 'Long': 143.05774605653642},
#  'aklavik': {'Lat': 67.23877493227357, 'Long': -138.57658770094392},
#  'aksha': {'Lat': 50.25468816564589, 'Long': 112.50017754548418},
#  'aksu': {'Lat': 37.45098697254811, 'Long': 81.88957576792654},
#  'aktau': {'Lat': 43.740045317752816, 'Long': 51.455046517862655},
#  'akyab': {'Lat': 17.322572377627907, 'Long': 91.36515102339843},
#  'albany': {'Lat': -75.74604513733851, 'Long': 104.87391776607484},
#  'alice springs': {'Lat': -26.25902914016099, 'Long': 138.72402642456},
#  'alofi': {'Lat': -21.703157134903265, 'Long': -167.03182337873676},
#  'along': {'Lat': 32.054550034495264, 'Long': 94.68369140304509},
#  'altamira': {'Lat': -3.888636833087091, 'Long': -53.058899226757404},
#  'alyangula': {'Lat': -13.80439676844479, 'Long': 139.6308726421763},
#  'amapa': {'Lat': 1.1961280219853307, 'Long': -50.806177814189795},
#  'amderma': {'Lat': 88.4324100905001, 'Long': 60.722344844697744},
#  'ancud': {'Lat': -42.26289682461686, 'Long': -106.80079082570043},
#  'antalaha': {'Lat': -14.114024663383034, 'Long': 52.84621423065187},
#  'arraial do cabo': {'Lat': -30.34089981695255, 'Long': -39.18931884480375},
#  'asfi': {'Lat': 33.64797690284303, 'Long': -12.206048804365963},
#  'ashland': {'Lat': 41.568997115381535, 'Long': -123.08824013738828},
#  'asyut': {'Lat': 22.82949358026822, 'Long': 25.5122814464564},
#  'at-bashi': {'Lat': 40.74772728796427, 'Long': 76.01910928430704},
#  'atambua': {'Lat': -10.337190771094953, 'Long': 125.93131445336115},
#  'atasu': {'Lat': 48.73888169898885, 'Long': 71.50996171504212},
#  'attawapiskat': {'Lat': 63.431986482185835, 'Long': -79.48712188399305},
#  'atuona': {'Lat': -3.0480211671997353, 'Long': -121.90411359985494},
#  'avarua': {'Lat': -21.83534569439871, 'Long': -159.5036367367019},
#  'axim': {'Lat': 0.6232677653834173, 'Long': -3.769472062315515},
#  'ayaviri': {'Lat': -14.94507745905534, 'Long': -70.46498602987495},
#  'aykhal': {'Lat': 68.38960526232049, 'Long': 107.94096165008193},
#  'baherden': {'Lat': 40.695999291757744, 'Long': 57.46910885739254},
#  'balikpapan': {'Lat': -1.3412285903120278, 'Long': 117.41461479135131},
#  'balsas': {'Lat': -7.932240218634675, 'Long': -45.39074935207111},
#  'bambanglipuro': {'Lat': -13.32551087944222, 'Long': 110.31279325843519},
#  'bambous virieux': {'Lat': -32.657858648151056, 'Long': 78.5948439046307},
#  'banda aceh': {'Lat': 4.738056237525754, 'Long': 89.77757374161826},
#  'bandarbeyla': {'Lat': 6.673779522079002, 'Long': 59.38247560396795},
#  'barabinsk': {'Lat': 55.506172503870545, 'Long': 78.02180544443559},
#  'barbar': {'Lat': 17.031616898303, 'Long': 35.02961314134723},
#  'barentsburg': {'Lat': 81.1033365711967, 'Long': -1.6194579129498266},
#  'barinas': {'Lat': 8.206401767463618, 'Long': -70.18318380750061},
#  'barranco': {'Lat': 9.479258249820361, 'Long': -83.06924416450653},
#  'barreirinhas': {'Lat': -0.9167039316054115, 'Long': -42.727136056937724},
#  'barroualie': {'Lat': 13.223800441780298, 'Long': -62.10936398179672},
#  'barrow': {'Lat': 87.67910149945007, 'Long': -161.50894966655235},
#  'baruun-urt': {'Lat': 46.545053409722044, 'Long': 112.72716090547647},
#  'batagay': {'Lat': 66.82471155042478, 'Long': 135.54543337545567},
#  'batagay-alyta': {'Lat': 68.26238702076591, 'Long': 131.22965360631633},
#  'bathsheba': {'Lat': 14.109150088107867, 'Long': -56.77764965284737},
#  'bati': {'Lat': 11.627739246520136, 'Long': 39.95190377184781},
#  'baykit': {'Lat': 62.22736255443476, 'Long': 95.42155300829609},
#  'bella union': {'Lat': -30.306125658514674, 'Long': -57.0963402544685},
#  'belmonte': {'Lat': -15.983623277665046, 'Long': -33.92953100812014},
#  'belushya guba': {'Lat': 86.72708968348155, 'Long': 43.09517604104954},
#  'bengkulu': {'Lat': -15.264845338429993, 'Long': 91.88684957785438},
#  'berbera': {'Lat': 11.403600420005674, 'Long': 46.53284681904569},
#  'berezovka': {'Lat': 51.226800792067564, 'Long': 127.18460787714889},
#  'beringovskiy': {'Lat': 54.473949038860894, 'Long': 178.82700991261794},
#  'berlevag': {'Lat': 74.90644089169442, 'Long': 29.62619947454857},
#  'beroroha': {'Lat': -20.763529968038526, 'Long': 45.63327379173356},
#  'bethel': {'Lat': 44.79240988621038, 'Long': -164.242279294129},
#  'bisauli': {'Lat': 28.390873401277304, 'Long': 78.94781295473427},
#  'bloomfield': {'Lat': 36.31820022562657, 'Long': -107.15462630862416},
#  'bluff': {'Lat': -81.61580040540277, 'Long': 160.3979505449832},
#  'bodri': {'Lat': 23.054826793904567, 'Long': 81.33436645502962},
#  'bolshegrivskoye': {'Lat': 53.52434859120325, 'Long': 75.33482651535479},
#  'fairbanks': {'Lat': 62.15732930596516, 'Long': -145.4237191054408},
#  'faya': {'Lat': 19.863670438945178, 'Long': 23.932395929470687},
#  'felidhoo': {'Lat': 3.4479140013205694, 'Long': 75.06903845701959},
#  'fevralsk': {'Lat': 52.36693105590814, 'Long': 131.24825510961193},
#  'flinders': {'Lat': -29.348030191777355, 'Long': 133.94709923352815},
#  'forestville': {'Lat': 49.4341577261776, 'Long': -69.91634251354529},
#  'fort nelson': {'Lat': 63.29398499031598, 'Long': -122.06131221721681},
#  'fortuna': {'Lat': 39.219936668095016, 'Long': -140.08208031753753},
#  'galiwinku': {'Lat': -9.530930967527851, 'Long': 136.28541545279165},
#  'galveston': {'Lat': 28.955093479390413, 'Long': -94.24167489549897},
#  'gao': {'Lat': 15.891187370815288, 'Long': -0.700940626706398},
#  'general pico': {'Lat': -36.004287297168055, 'Long': -64.21493567845302},
#  'george town': {'Lat': 17.826739848707348, 'Long': -82.6004451210202},
#  'georgetown': {'Lat': -16.293051024164512, 'Long': -16.142739663033893},
#  'geraldton': {'Lat': -31.64417911757011, 'Long': 95.87846696744691},
#  'gewane': {'Lat': 10.660963992102353, 'Long': 40.416743931929034},
#  'gigmoto': {'Lat': 14.87584559904036, 'Long': 126.60419562631392},
#  'ginda': {'Lat': 15.144807057048297, 'Long': 39.850386374286444},
#  'gizo': {'Lat': -10.208370319584006, 'Long': 157.35838779969134},
#  'goderich': {'Lat': 3.9139373056623157, 'Long': -18.696813891713845},
#  'gondar': {'Lat': 12.909784699799928, 'Long': 37.03649002052978},
#  'grand island': {'Lat': 40.92314332293668, 'Long': -98.26992829266604},
#  'grand river south east': {'Lat': -23.05353265685831,
#                             'Long': 67.84282200172396},
#  'gravdal': {'Lat': 69.37756118567063, 'Long': 12.34582705962336},
#  'grindavik': {'Lat': 59.784543708073244, 'Long': -25.81345398674037},
#  'guerrero negro': {'Lat': 24.12030288762149, 'Long': -117.26753842301694},
#  'guican': {'Lat': 6.358206680632293, 'Long': -72.28322998588978},
#  'haines junction': {'Lat': 58.200534754792955, 'Long': -140.60426389398157},
#  'halalo': {'Lat': -13.823889872902214, 'Long': -179.0256987737932},
#  'half moon bay': {'Lat': 28.617359395105026, 'Long': -138.50490650434432},
#  'halifax': {'Lat': 42.61651109786837, 'Long': -61.46664346162119},
#  'hamadan': {'Lat': 34.760955529688474, 'Long': 48.91203681546054},
#  'hambantota': {'Lat': -5.546138724731819, 'Long': 84.49725991196908},
#  'harper': {'Lat': -1.9759569923625833, 'Long': -10.036815495240745},
#  'hasaki': {'Lat': 29.515972079497487, 'Long': 151.36670592812703},
#  'havelock': {'Lat': 32.02338237626245, 'Long': -73.09282000483078},
#  'hays': {'Lat': 39.27480449129635, 'Long': -100.58289132232186},
#  'hegang': {'Lat': 47.441759625840916, 'Long': 130.22972745791537},
#  'hermanus': {'Lat': -83.6408278919653, 'Long': -2.2165770978215846},
#  'hihifo': {'Lat': -16.521249249973096, 'Long': -175.92314725346057},
#  'hilo': {'Lat': 4.849588442224658, 'Long': -147.89628283635145},
#  'yakeshi': {'Lat': 48.52423061157438, 'Long': 120.44873209001463},
#  'yakima': {'Lat': 46.096550487254234, 'Long': -121.05393295705892},
#  'yamada': {'Lat': 37.940174674849274, 'Long': 146.60131175171563},
#  'yanan': {'Lat': 38.05495970792995, 'Long': 109.14162612624114},
#  'yar-sale': {'Lat': 74.03077042836259, 'Long': 69.3922681010373},
#  'yarmouth': {'Lat': 40.80279827906128, 'Long': -66.64560717898536},
#  'yatou': {'Lat': 37.14190888400627, 'Long': 122.2218377141811},
#  'yellowknife': {'Lat': 88.75145859845796, 'Long': -111.08678788965297},
#  'yulara': {'Lat': -28.44588108619618, 'Long': 128.97384367819205},
#  'zambezi': {'Lat': -12.651883132510903, 'Long': 22.935260337994947},
#  'zhengjiatun': {'Lat': 42.964616724332586, 'Long': 123.4413532743365},
#  'zhezkazgan': {'Lat': 46.8294660804016, 'Long': 66.52994697885785},
#  'zhicheng': {'Lat': 27.803521479501896, 'Long': 118.6963572461114},
#  'zhigansk': {'Lat': 65.72408958328242, 'Long': 124.48279529533119},
#  'zhuhai': {'Lat': 18.598593249711953, 'Long': 114.8325677799877}}

# %%
#construct API query code
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

#build partial query URL
query_url = (f"{url}appid={api_key}&units={units}&q=")

#test url and show sample to find location of desired data
response = requests.get(query_url + "Nashville").json()
pprint(response)

#store date
date = datetime.utcfromtimestamp(response["dt"]).strftime('%Y-%m-%d')
# Out:
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 36.16, 'lon': -86.77},
#  'dt': 1569087981,
#  'id': 4644585,
#  'main': {'humidity': 33,
#           'pressure': 1024,
#           'temp': 30.43,
#           'temp_max': 31.67,
#           'temp_min': 29},
#  'name': 'Nashville',
#  'sys': {'country': 'US',
#          'id': 4609,
#          'message': 0.0087,
#          'sunrise': 1569065642,
#          'sunset': 1569109590,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 190, 'speed': 3.6}}

# %%
#Get temperature, humidity, cloudiness, and wind speed for each city from API
set_num = 1
city_num = 0
oops = []
for city in city_stats:
    ###dear API, please give me what I want
    response = requests.get(query_url + city).json()
    city_num += 1
    try:
    #update city_stats (overwriting current coords) with retrieved stats
        city_stats[city]["Temperature"] = response["main"]["temp_max"]
        city_stats[city]["Humidity"] = response["main"]["humidity"]
        city_stats[city]["Cloudiness"] = response["clouds"]["all"]
        city_stats[city]["Wind speed"] = response["wind"]["speed"]
        city_stats[city]["Date"] = datetime.utcfromtimestamp(response["dt"]).strftime('%Y-%m-%d')
        city_stats[city]["Country"] = response["sys"]["country"]
        print(f"Processing city {city_num} of set {set_num}: {city}")
    except KeyError:
        print(f'"{city}" not found.  Removing from list...')
        oops.append(city)
    if "coord" in response:
        city_stats[city]["Lat"] = response["coord"]["lat"]
        city_stats[city]["Long"] = response["coord"]["lon"]
    if city_num >= 50:
        set_num += 1
        city_num = 0
        time.sleep(1)
for city in oops:
    del city_stats[city]

# Processing city 1 of set 11: leningradskiy
# Processing city 2 of set 11: wanning
# Processing city 3 of set 11: enniskerry
# Processing city 4 of set 11: portland
# Processing city 5 of set 11: xinqing
# Processing city 6 of set 11: tandalti
# Processing city 7 of set 11: port elizabeth
# Processing city 8 of set 11: aksu
# Processing city 9 of set 11: killybegs
# Processing city 10 of set 11: kotka
# Processing city 11 of set 11: manzil salim
# Processing city 12 of set 11: namie
# Processing city 13 of set 11: palivere
# Processing city 14 of set 11: romitan
# Processing city 15 of set 11: seoul
# Processing city 16 of set 11: tarata
# Processing city 17 of set 11: esmeraldas
# Processing city 18 of set 11: madimba
# Processing city 19 of set 11: kambove
# Processing city 20 of set 11: sorland
# Processing city 21 of set 11: eggenfelden
# Processing city 22 of set 11: bonavista
# Processing city 23 of set 11: barranco
# Processing city 24 of set 11: teknaf
# Processing city 25 of set 11: galveston
# Processing city 26 of set 11: aden
# Processing city 27 of set 11: tayu
# Processing city 28 of set 11: kargopol
# Processing city 29 of set 11: redmond
# Processing city 30 of set 11: tianpeng
# Processing city 31 of set 11: ligayan
# Processing city 32 of set 11: maniitsoq
# Processing city 33 of set 11: salvador
# Processing city 34 of set 11: sobolevo
# Processing city 35 of set 11: domingos martins
# Processing city 36 of set 11: zambezi
# Processing city 37 of set 11: yakima
# Processing city 38 of set 11: moyale
# Processing city 39 of set 11: hueyotlipan
# Processing city 40 of set 11: maxixe
# ---------------------------------------------
# Cities successfully added: 540
# Cities omitted: 0

# %%
pprint(city_stats)
# Out:
# {'abu dhabi': {'Cloudiness': 0,
#                'Country': 'AE',
#                'Date': '2019-09-21',
#                'Humidity': 75,
#                'Lat': 24.47,
#                'Long': 54.37,
#                'Temperature': 33,
#                'Wind speed': 2.6},
#  'adaufe': {'Cloudiness': 75,
#             'Country': 'PT',
#             'Date': '2019-09-21',
#             'Humidity': 93,
#             'Lat': 40.89,
#             'Long': -8.24,
#             'Temperature': 18.89,
#             'Wind speed': 1.5},
#  'aden': {'Cloudiness': 9,
#           'Country': 'YE',
#           'Date': '2019-09-21',
#           'Humidity': 49,
#           'Lat': 12.79,
#           'Long': 45.03,
#           'Temperature': 32.7,
#           'Wind speed': 3.17},
#  'adrar': {'Cloudiness': 65,
#            'Country': 'DZ',
#            'Date': '2019-09-21',
#            'Humidity': 10,
#            'Lat': 27.87,
#            'Long': -0.29,
#            'Temperature': 42,
#            'Wind speed': 4.1},
#  'agadir': {'Cloudiness': 0,
#             'Country': 'MA',
#             'Date': '2019-09-21',
#             'Humidity': 60,
#             'Lat': 30.42,
#             'Long': -9.58,
#             'Temperature': 24,
#             'Wind speed': 6.7},
#  'agra': {'Cloudiness': 75,
#           'Country': 'IN',
#           'Date': '2019-09-21',
#           'Humidity': 100,
#           'Lat': 27.18,
#           'Long': 78.01,
#           'Temperature': 25,
#           'Wind speed': 0.5},
#  'ahipara': {'Cloudiness': 0,
#              'Country': 'NZ',
#              'Date': '2019-09-21',
#              'Humidity': 100,
#              'Lat': -35.17,
#              'Long': 173.16,
#              'Temperature': 6.67,
#              'Wind speed': 4.74},
#  'ahmadnagar': {'Cloudiness': 94,
#                 'Country': 'IN',
#                 'Date': '2019-09-21',
#                 'Humidity': 80,
#                 'Lat': 19.09,
#                 'Long': 74.75,
#                 'Temperature': 23.7,
#                 'Wind speed': 3.17},
#  'ahuimanu': {'Cloudiness': 40,
#               'Country': 'US',
#               'Date': '2019-09-21',
#               'Humidity': 88,
#               'Lat': 21.44,
#               'Long': -157.84,
#               'Temperature': 27.22,
#               'Wind speed': 1.5},
#  'airai': {'Cloudiness': 61,
#            'Country': 'TL',
#            'Date': '2019-09-21',
#            'Humidity': 80,
#            'Lat': -8.93,
#            'Long': 125.41,
#            'Temperature': 19.3,
#            'Wind speed': 1.21},
#  'aitape': {'Cloudiness': 88,
#             'Country': 'PG',
#             'Date': '2019-09-21',
#             'Humidity': 80,
#             'Lat': -3.15,
#             'Long': 142.36,
#             'Temperature': 24.2,
#             'Wind speed': 1.93},
#  'aklavik': {'Cloudiness': 90,
#              'Country': 'CA',
#              'Date': '2019-09-21',
#              'Humidity': 93,
#              'Lat': 68.22,
#              'Long': -135.01,
#              'Temperature': 6,
#              'Wind speed': 1.5},
#  'aksha': {'Cloudiness': 1,
#            'Country': 'RU',
#            'Date': '2019-09-21',
#            'Humidity': 81,
#            'Lat': 50.28,
#            'Long': 113.29,
#            'Temperature': 7.6,
#            'Wind speed': 1.24},
#  'aksu': {'Cloudiness': 0,
#           'Country': 'KZ',
#           'Date': '2019-09-21',
#           'Humidity': 46,
#           'Lat': 52.04,
#           'Long': 76.93,
#           'Temperature': 10,
#           'Wind speed': 4},
#  'aktau': {'Cloudiness': 75,
#            'Country': 'KZ',
#            'Date': '2019-09-21',
#            'Humidity': 67,
#            'Lat': 43.65,
#            'Long': 51.16,
#            'Temperature': 15,
#            'Wind speed': 9},
#  'albany': {'Cloudiness': 1,
#             'Country': 'US',
#             'Date': '2019-09-21',
#             'Humidity': 47,
#             'Lat': 42.65,
#             'Long': -73.75,
#             'Temperature': 27.22,
#             'Wind speed': 1.26},
#  'alice springs': {'Cloudiness': 75,
#                    'Country': 'AU',
#                    'Date': '2019-09-21',
#                    'Humidity': 31,
#                    'Lat': -23.7,
#                    'Long': 133.88,
#                    'Temperature': 9,
#                    'Wind speed': 1.5},
#  'alofi': {'Cloudiness': 96,
#            'Country': 'NU',
#            'Date': '2019-09-21',
#            'Humidity': 100,
#            'Lat': -19.06,
#            'Long': -169.92,
#            'Temperature': 19,
#            'Wind speed': 3.6},
#  'along': {'Cloudiness': 100,
#            'Country': 'IN',
#            'Date': '2019-09-21',
#            'Humidity': 95,
#            'Lat': 28.17,
#            'Long': 94.8,
#            'Temperature': 14,
#            'Wind speed': 1.9},
#  'altamira': {'Cloudiness': 90,
#               'Country': 'BR',
#               'Date': '2019-09-21',
#               'Humidity': 30,
#               'Lat': -3.2,
#               'Long': -52.21,
#               'Temperature': 37.8,
#               'Wind speed': 2.15},
#  'alyangula': {'Cloudiness': 17,
#                'Country': 'AU',
#                'Date': '2019-09-21',
#                'Humidity': 94,
#                'Lat': -13.85,
#                'Long': 136.42,
#                'Temperature': 21,
#                'Wind speed': 1.5},
#  'amapa': {'Cloudiness': 40,
#            'Country': 'HN',
#            'Date': '2019-09-21',
#            'Humidity': 52,
#            'Lat': 15.09,
#            'Long': -87.97,
#            'Temperature': 33,
#            'Wind speed': 2.1},
#  'ancud': {'Cloudiness': 40,
#            'Country': 'CL',
#            'Date': '2019-09-21',
#            'Humidity': 61,
#            'Lat': -41.87,
#            'Long': -73.83,
#            'Temperature': 10,
#            'Wind speed': 1.5},
#  'antalaha': {'Cloudiness': 76,
#               'Country': 'MG',
#               'Date': '2019-09-21',
#               'Humidity': 98,
#               'Lat': -14.9,
#               'Long': 50.28,
#               'Temperature': 15.6,
#               'Wind speed': 1.6},
#  'arraial do cabo': {'Cloudiness': 75,
#                      'Country': 'BR',
#                      'Date': '2019-09-21',
#                      'Humidity': 78,
#                      'Lat': -22.97,
#                      'Long': -42.02,
#                      'Temperature': 26,
#                      'Wind speed': 5.1},
#  'ashland': {'Cloudiness': 75,
#              'Country': 'US',
#              'Date': '2019-09-21',
#              'Humidity': 58,
#              'Lat': 38.48,
#              'Long': -82.64,
#              'Temperature': 30.56,
#              'Wind speed': 3.17},
#  'asyut': {'Cloudiness': 0,
#            'Country': 'EG',
#            'Date': '2019-09-21',
#            'Humidity': 38,
#            'Lat': 27.18,
#            'Long': 31.19,
#            'Temperature': 31,
#            'Wind speed': 6.2},
#  'at-bashi': {'Cloudiness': 0,
#               'Country': 'KG',
#               'Date': '2019-09-21',
#               'Humidity': 34,
#               'Lat': 41.17,
#               'Long': 75.81,
#               'Temperature': 11.2,
#               'Wind speed': 3.1},
#  'atambua': {'Cloudiness': 33,
#              'Country': 'ID',
#              'Date': '2019-09-21',
#              'Humidity': 78,
#              'Lat': -9.11,
#              'Long': 124.89,
#              'Temperature': 23.9,
#              'Wind speed': 3.44},
#  'atasu': {'Cloudiness': 24,
#            'Country': 'KZ',
#            'Date': '2019-09-21',
#            'Humidity': 32,
#            'Lat': 48.68,
#            'Long': 71.64,
#            'Temperature': 18.5,
#            'Wind speed': 6.39},
#  'atuona': {'Cloudiness': 8,
#             'Country': 'PF',
#             'Date': '2019-09-21',
#             'Humidity': 78,
#             'Lat': -9.8,
#             'Long': -139.03,
#             'Temperature': 26.9,
#             'Wind speed': 10.62},
#  'avarua': {'Cloudiness': 83,
#             'Country': 'CK',
#             'Date': '2019-09-21',
#             'Humidity': 94,
#             'Lat': -21.21,
#             'Long': -159.78,
#             'Temperature': 20,
#             'Wind speed': 0.5},
#  'axim': {'Cloudiness': 100,
#           'Country': 'GH',
#           'Date': '2019-09-21',
#           'Humidity': 88,
#           'Lat': 4.87,
#           'Long': -2.24,
#           'Temperature': 25.2,
#           'Wind speed': 4.27},
#  'ayaviri': {'Cloudiness': 88,
#              'Country': 'PE',
#              'Date': '2019-09-21',
#              'Humidity': 35,
#              'Lat': -14.88,
#              'Long': -70.59,
#              'Temperature': 12.9,
#              'Wind speed': 3.07},
#  'aykhal': {'Cloudiness': 59,
#             'Country': 'RU',
#             'Date': '2019-09-21',
#             'Humidity': 93,
#             'Lat': 65.95,
#             'Long': 111.51,
#             'Temperature': 1.1,
#             'Wind speed': 8.8},
#  'baherden': {'Cloudiness': 0,
#               'Country': 'TM',
#               'Date': '2019-09-21',
#               'Humidity': 22,
#               'Lat': 38.44,
#               'Long': 57.43,
#               'Temperature': 24.2,
#               'Wind speed': 1.74},
#  'balikpapan': {'Cloudiness': 8,
#                 'Country': 'ID',
#                 'Date': '2019-09-21',
#                 'Humidity': 99,
#                 'Lat': -1.24,
#                 'Long': 116.86,
#                 'Temperature': 21.6,
#                 'Wind speed': 0.89},
#  'balsas': {'Cloudiness': 0,
#             'Country': 'BR',
#             'Date': '2019-09-21',
#             'Humidity': 16,
#             'Lat': -7.53,
#             'Long': -46.04,
#             'Temperature': 39.6,
#             'Wind speed': 2.99},
#  'bambanglipuro': {'Cloudiness': 90,
#                    'Country': 'ID',
#                    'Date': '2019-09-21',
#                    'Humidity': 86,
#                    'Lat': -7.95,
#                    'Long': 110.28,
#                    'Temperature': 23.1,
#                    'Wind speed': 3.92},
#  'bambous virieux': {'Cloudiness': 75,
#                      'Country': 'MU',
#                      'Date': '2019-09-21',
#                      'Humidity': 88,
#                      'Lat': -20.34,
#                      'Long': 57.76,
#                      'Temperature': 20.56,
#                      'Wind speed': 8.2},
#  'banda aceh': {'Cloudiness': 94,
#                 'Country': 'ID',
#                 'Date': '2019-09-21',
#                 'Humidity': 79,
#                 'Lat': 5.56,
#                 'Long': 95.32,
#                 'Temperature': 28,
#                 'Wind speed': 6.76},
#  'bandarbeyla': {'Cloudiness': 74,
#                  'Country': 'SO',
#                  'Date': '2019-09-21',
#                  'Humidity': 76,
#                  'Lat': 9.49,
#                  'Long': 50.81,
#                  'Temperature': 24.3,
#                  'Wind speed': 10},
#  'barabinsk': {'Cloudiness': 70,
#                'Country': 'RU',
#                'Date': '2019-09-21',
#                'Humidity': 75,
#                'Lat': 55.35,
#                'Long': 78.35,
#                'Temperature': 8.7,
#                'Wind speed': 2.77},
#  'barinas': {'Cloudiness': 98,
#              'Country': 'VE',
#              'Date': '2019-09-21',
#              'Humidity': 61,
#              'Lat': 8.64,
#              'Long': -70.23,
#              'Temperature': 31.2,
#              'Wind speed': 2.45},
#  'barranco': {'Cloudiness': 0,
#               'Country': 'BR',
#               'Date': '2019-09-21',
#               'Humidity': 34,
#               'Lat': -20.59,
#               'Long': -41.2,
#               'Temperature': 31.8,
#               'Wind speed': 2.2},
#  'barreirinhas': {'Cloudiness': 0,
#                   'Country': 'BR',
#                   'Date': '2019-09-21',
#                   'Humidity': 34,
#                   'Lat': -2.75,
#                   'Long': -42.83,
#                   'Temperature': 35.4,
#                   'Wind speed': 4.9},
#  'barrow': {'Cloudiness': 32,
#             'Country': 'AR',
#             'Date': '2019-09-21',
#             'Humidity': 39,
#             'Lat': -38.31,
#             'Long': -60.23,
#             'Temperature': 15,
#             'Wind speed': 7.47},
#  'baruun-urt': {'Cloudiness': 0,
#                 'Country': 'MN',
#                 'Date': '2019-09-21',
#                 'Humidity': 49,
#                 'Lat': 46.68,
#                 'Long': 113.28,
#                 'Temperature': 10.6,
#                 'Wind speed': 3.33},
#  'batagay': {'Cloudiness': 0,
#              'Country': 'RU',
#              'Date': '2019-09-21',
#              'Humidity': 86,
#              'Lat': 67.65,
#              'Long': 134.64,
#              'Temperature': -0.81,
#              'Wind speed': 1.49},
#  'batagay-alyta': {'Cloudiness': 96,
#                    'Country': 'RU',
#                    'Date': '2019-09-21',
#                    'Humidity': 92,
#                    'Lat': 67.8,
#                    'Long': 130.41,
#                    'Temperature': -5.11,
#                    'Wind speed': 1.15},
#  'bathsheba': {'Cloudiness': 40,
#                'Country': 'BB',
#                'Date': '2019-09-21',
#                'Humidity': 66,
#                'Lat': 13.22,
#                'Long': -59.52,
#                'Temperature': 31,
#                'Wind speed': 10.3},
#  'bati': {'Cloudiness': 94,
#           'Country': 'ET',
#           'Date': '2019-09-21',
#           'Humidity': 75,
#           'Lat': 11.19,
#           'Long': 40.02,
#           'Temperature': 19.1,
#           'Wind speed': 4.4},
#  'baykit': {'Cloudiness': 100,
#             'Country': 'RU',
#             'Date': '2019-09-21',
#             'Humidity': 92,
#             'Lat': 61.68,
#             'Long': 96.39,
#             'Temperature': 3.4,
#             'Wind speed': 4.16},
#  'bella union': {'Cloudiness': 100,
#                  'Country': 'CO',
#                  'Date': '2019-09-21',
#                  'Humidity': 92,
#                  'Lat': 8.5,
#                  'Long': -73.35,
#                  'Temperature': 22.3,
#                  'Wind speed': 1.26},
#  'belmonte': {'Cloudiness': 96,
#               'Country': 'PT',
#               'Date': '2019-09-21',
#               'Humidity': 86,
#               'Lat': 40.36,
#               'Long': -7.35,
#               'Temperature': 17.22,
#               'Wind speed': 3},
#  'berezovka': {'Cloudiness': 21,
#                'Country': 'RU',
#                'Date': '2019-09-21',
#                'Humidity': 76,
#                'Lat': 55.71,
#                'Long': 42.61,
#                'Temperature': 3,
#                'Wind speed': 2.17},
#  'beringovskiy': {'Cloudiness': 14,
#                   'Country': 'RU',
#                   'Date': '2019-09-21',
#                   'Humidity': 72,
#                   'Lat': 63.05,
#                   'Long': 179.32,
#                   'Temperature': -1.91,
#                   'Wind speed': 2.24},
#  'berlevag': {'Cloudiness': 99,
#               'Country': 'NO',
#               'Date': '2019-09-21',
#               'Humidity': 71,
#               'Lat': 70.86,
#               'Long': 29.09,
#               'Temperature': 4.9,
#               'Wind speed': 5.9},
#  'beroroha': {'Cloudiness': 0,
#               'Country': 'MG',
#               'Date': '2019-09-21',
#               'Humidity': 48,
#               'Lat': -21.68,
#               'Long': 45.17,
#               'Temperature': 23.4,
#               'Wind speed': 2.08},
#  'bethel': {'Cloudiness': 20,
#             'Country': 'US',
#             'Date': '2019-09-21',
#             'Humidity': 100,
#             'Lat': 60.79,
#             'Long': -161.76,
#             'Temperature': 3,
#             'Wind speed': 3.6},
#  'bisauli': {'Cloudiness': 0,
#              'Country': 'IN',
#              'Date': '2019-09-21',
#              'Humidity': 73,
#              'Lat': 28.31,
#              'Long': 78.94,
#              'Temperature': 27,
#              'Wind speed': 2.41},
#  'bloomfield': {'Cloudiness': 75,
#                 'Country': 'US',
#                 'Date': '2019-09-21',
#                 'Humidity': 94,
#                 'Lat': 40.75,
#                 'Long': -92.42,
#                 'Temperature': 23,
#                 'Wind speed': 6.2},
#  'bluff': {'Cloudiness': 0,
#            'Country': 'AU',
#            'Date': '2019-09-21',
#            'Humidity': 93,
#            'Lat': -23.58,
#            'Long': 149.07,
#            'Temperature': 14.6,
#            'Wind speed': 3.34},
#  'bodri': {'Cloudiness': 95,
#            'Country': 'IN',
#            'Date': '2019-09-21',
#            'Humidity': 91,
#            'Lat': 23.17,
#            'Long': 81.43,
#            'Temperature': 22.6,
#            'Wind speed': 1.74},
#  'bonavista': {'Cloudiness': 78,
#                'Country': 'CA',
#                'Date': '2019-09-21',
#                'Humidity': 86,
#                'Lat': 48.65,
#                'Long': -53.11,
#                'Temperature': 9.44,
#                'Wind speed': 4.92},
#  'borovichi': {'Cloudiness': 100,
#                'Country': 'RU',
#                'Date': '2019-09-21',
#                'Humidity': 97,
#                'Lat': 58.39,
#                'Long': 33.91,
#                'Temperature': 4.7,
#                'Wind speed': 1.98},
#  'bose': {'Cloudiness': 100,
#           'Country': 'IT',
#           'Date': '2019-09-21',
#           'Humidity': 59,
#           'Lat': 45.46,
#           'Long': 8.01,
#           'Temperature': 20,
#           'Wind speed': 5.1},
#  'bowen': {'Cloudiness': 75,
#            'Country': 'AU',
#            'Date': '2019-09-21',
#            'Humidity': 93,
#            'Lat': -20.01,
#            'Long': 148.25,
#            'Temperature': 18,
#            'Wind speed': 3.1},
#  'boyolangu': {'Cloudiness': 60,
#                'Country': 'ID',
#                'Date': '2019-09-21',
#                'Humidity': 94,
#                'Lat': -8.09,
#                'Long': 111.9,
#                'Temperature': 19,
#                'Wind speed': 2.07},
#  'brae': {'Cloudiness': 2,
#           'Country': 'GB',
#           'Date': '2019-09-21',
#           'Humidity': 87,
#           'Lat': 60.4,
#           'Long': -1.35,
#           'Temperature': 13,
#           'Wind speed': 11.8},
#  'bredasdorp': {'Cloudiness': 85,
#                 'Country': 'ZA',
#                 'Date': '2019-09-21',
#                 'Humidity': 87,
#                 'Lat': -34.53,
#                 'Long': 20.04,
#                 'Temperature': 14,
#                 'Wind speed': 3.6},
#  'brest': {'Cloudiness': 86,
#            'Country': 'BY',
#            'Date': '2019-09-21',
#            'Humidity': 78,
#            'Lat': 52.09,
#            'Long': 23.69,
#            'Temperature': 12.2,
#            'Wind speed': 4.45},
#  'broken hill': {'Cloudiness': 0,
#                  'Country': 'AU',
#                  'Date': '2019-09-21',
#                  'Humidity': 75,
#                  'Lat': -31.97,
#                  'Long': 141.45,
#                  'Temperature': 7,
#                  'Wind speed': 1.5},
#  'broome': {'Cloudiness': 0,
#             'Country': 'GB',
#             'Date': '2019-09-21',
#             'Humidity': 63,
#             'Lat': 52.47,
#             'Long': 1.45,
#             'Temperature': 20,
#             'Wind speed': 5.1},
#  'bubaque': {'Cloudiness': 14,
#              'Country': 'GW',
#              'Date': '2019-09-21',
#              'Humidity': 76,
#              'Lat': 11.28,
#              'Long': -15.83,
#              'Temperature': 28.1,
#              'Wind speed': 4.14},
#  'buchanan': {'Cloudiness': 75,
#               'Country': 'LR',
#               'Date': '2019-09-21',
#               'Humidity': 94,
#               'Lat': 5.88,
#               'Long': -10.05,
#               'Temperature': 25,
#               'Wind speed': 5.22},
#  'busselton': {'Cloudiness': 0,
#                'Country': 'AU',
#                'Date': '2019-09-21',
#                'Humidity': 60,
#                'Lat': -33.64,
#                'Long': 115.35,
#                'Temperature': 5,
#                'Wind speed': 5.6},
#  'butaritari': {'Cloudiness': 6,
#                 'Country': 'KI',
#                 'Date': '2019-09-21',
#                 'Humidity': 59,
#                 'Lat': 3.07,
#                 'Long': 172.79,
#                 'Temperature': 29.1,
#                 'Wind speed': 2.85},
#  'cabo san lucas': {'Cloudiness': 75,
#                     'Country': 'MX',
#                     'Date': '2019-09-21',
#                     'Humidity': 83,
#                     'Lat': 22.89,
#                     'Long': -109.91,
#                     'Temperature': 31.67,
#                     'Wind speed': 6.7},
#  'calbuco': {'Cloudiness': 75,
#              'Country': 'CL',
#              'Date': '2019-09-21',
#              'Humidity': 66,
#              'Lat': -41.77,
#              'Long': -73.13,
#              'Temperature': 10,
#              'Wind speed': 3.6},
#  'camacha': {'Cloudiness': 40,
#              'Country': 'PT',
#              'Date': '2019-09-21',
#              'Humidity': 83,
#              'Lat': 33.08,
#              'Long': -16.33,
#              'Temperature': 24,
#              'Wind speed': 4.6},
#  'cape town': {'Cloudiness': 75,
#                'Country': 'ZA',
#                'Date': '2019-09-21',
#                'Humidity': 82,
#                'Lat': -33.93,
#                'Long': 18.42,
#                'Temperature': 15.56,
#                'Wind speed': 4.6},
#  'caravelas': {'Cloudiness': 43,
#                'Country': 'BR',
#                'Date': '2019-09-21',
#                'Humidity': 63,
#                'Lat': -17.73,
#                'Long': -39.27,
#                'Temperature': 26.4,
#                'Wind speed': 6.84},
#  'carbondale': {'Cloudiness': 90,
#                 'Country': 'US',
#                 'Date': '2019-09-21',
#                 'Humidity': 83,
#                 'Lat': 38.82,
#                 'Long': -95.69,
#                 'Temperature': 26.11,
#                 'Wind speed': 6.7},
#  'carnarvon': {'Cloudiness': 87,
#                'Country': 'ZA',
#                'Date': '2019-09-21',
#                'Humidity': 30,
#                'Lat': -30.97,
#                'Long': 22.13,
#                'Temperature': 17,
#                'Wind speed': 10.5},
#  'castro': {'Cloudiness': 40,
#             'Country': 'CL',
#             'Date': '2019-09-21',
#             'Humidity': 61,
#             'Lat': -42.48,
#             'Long': -73.76,
#             'Temperature': 10,
#             'Wind speed': 1.5},
#  'cayenne': {'Cloudiness': 0,
#              'Country': 'GF',
#              'Date': '2019-09-21',
#              'Humidity': 59,
#              'Lat': 4.94,
#              'Long': -52.33,
#              'Temperature': 32,
#              'Wind speed': 6.7},
#  'ceres': {'Cloudiness': 43,
#            'Country': 'BR',
#            'Date': '2019-09-21',
#            'Humidity': 17,
#            'Lat': -15.31,
#            'Long': -49.6,
#            'Temperature': 36.6,
#            'Wind speed': 2.95},
#  'cervo': {'Cloudiness': 66,
#            'Country': 'BR',
#            'Date': '2019-09-21',
#            'Humidity': 72,
#            'Lat': -22.19,
#            'Long': -46.24,
#            'Temperature': 22.8,
#            'Wind speed': 1.89},
#  'challans': {'Cloudiness': 0,
#               'Country': 'FR',
#               'Date': '2019-09-21',
#               'Humidity': 53,
#               'Lat': 46.85,
#               'Long': -1.88,
#               'Temperature': 24.44,
#               'Wind speed': 5.1},
#  'challapata': {'Cloudiness': 23,
#                 'Country': 'BO',
#                 'Date': '2019-09-21',
#                 'Humidity': 59,
#                 'Lat': -18.9,
#                 'Long': -66.78,
#                 'Temperature': 11.5,
#                 'Wind speed': 3.83},
#  'champerico': {'Cloudiness': 75,
#                 'Country': 'MX',
#                 'Date': '2019-09-21',
#                 'Humidity': 65,
#                 'Lat': 16.38,
#                 'Long': -93.6,
#                 'Temperature': 28,
#                 'Wind speed': 1.5},
#  'changji': {'Cloudiness': 0,
#              'Country': 'CN',
#              'Date': '2019-09-21',
#              'Humidity': 86,
#              'Lat': 32.07,
#              'Long': 116.17,
#              'Temperature': 17.4,
#              'Wind speed': 2.18},
#  'chara': {'Cloudiness': 20,
#            'Country': 'GR',
#            'Date': '2019-09-21',
#            'Humidity': 59,
#            'Lat': 39.42,
#            'Long': 22.43,
#            'Temperature': 19,
#            'Wind speed': 3.1},
#  'chermoz': {'Cloudiness': 39,
#              'Country': 'RU',
#              'Date': '2019-09-21',
#              'Humidity': 95,
#              'Lat': 58.79,
#              'Long': 56.15,
#              'Temperature': 1.5,
#              'Wind speed': 4.06},
#  'cherskiy': {'Cloudiness': 97,
#               'Country': 'RU',
#               'Date': '2019-09-21',
#               'Humidity': 94,
#               'Lat': 68.75,
#               'Long': 161.3,
#               'Temperature': -2.61,
#               'Wind speed': 3.24},
#  'chisec': {'Cloudiness': 23,
#             'Country': 'GT',
#             'Date': '2019-09-21',
#             'Humidity': 55,
#             'Lat': 15.81,
#             'Long': -90.29,
#             'Temperature': 31.3,
#             'Wind speed': 1.64},
#  'chokurdakh': {'Cloudiness': 51,
#                 'Country': 'RU',
#                 'Date': '2019-09-21',
#                 'Humidity': 87,
#                 'Lat': 70.62,
#                 'Long': 147.9,
#                 'Temperature': -4.01,
#                 'Wind speed': 2.1},
#  'chunskiy': {'Cloudiness': 75,
#               'Country': 'RU',
#               'Date': '2019-09-21',
#               'Humidity': 89,
#               'Lat': 56.08,
#               'Long': 99.63,
#               'Temperature': 6.9,
#               'Wind speed': 1.62},
#  'chuy': {'Cloudiness': 0,
#           'Country': 'UY',
#           'Date': '2019-09-21',
#           'Humidity': 46,
#           'Lat': -33.69,
#           'Long': -53.46,
#           'Temperature': 17.7,
#           'Wind speed': 4.66},
#  'cidreira': {'Cloudiness': 0,
#               'Country': 'BR',
#               'Date': '2019-09-21',
#               'Humidity': 50,
#               'Lat': -30.17,
#               'Long': -50.22,
#               'Temperature': 17.7,
#               'Wind speed': 3.8},
#  'ciro marina': {'Cloudiness': 0,
#                  'Country': 'IT',
#                  'Date': '2019-09-21',
#                  'Humidity': 64,
#                  'Lat': 39.37,
#                  'Long': 17.13,
#                  'Temperature': 21,
#                  'Wind speed': 3.1},
#  'clonakilty': {'Cloudiness': 75,
#                 'Country': 'IE',
#                 'Date': '2019-09-21',
#                 'Humidity': 100,
#                 'Lat': 51.62,
#                 'Long': -8.87,
#                 'Temperature': 16,
#                 'Wind speed': 9.3},
#  'clyde river': {'Cloudiness': 90,
#                  'Country': 'CA',
#                  'Date': '2019-09-21',
#                  'Humidity': 95,
#                  'Lat': 70.47,
#                  'Long': -68.59,
#                  'Temperature': 1,
#                  'Wind speed': 12.3},
#  'coahuayana': {'Cloudiness': 48,
#                 'Country': 'MX',
#                 'Date': '2019-09-21',
#                 'Humidity': 75,
#                 'Lat': 18.62,
#                 'Long': -100.35,
#                 'Temperature': 27.7,
#                 'Wind speed': 0.83},
#  'cockburn town': {'Cloudiness': 75,
#                    'Country': 'TC',
#                    'Date': '2019-09-21',
#                    'Humidity': 52,
#                    'Lat': 21.46,
#                    'Long': -71.14,
#                    'Temperature': 32,
#                    'Wind speed': 4.1},
#  'codrington': {'Cloudiness': 21,
#                 'Country': 'AU',
#                 'Date': '2019-09-21',
#                 'Humidity': 93,
#                 'Lat': -28.95,
#                 'Long': 153.24,
#                 'Temperature': 19,
#                 'Wind speed': 2.1},
#  'college': {'Cloudiness': 90,
#              'Country': 'US',
#              'Date': '2019-09-21',
#              'Humidity': 93,
#              'Lat': 64.86,
#              'Long': -147.8,
#              'Temperature': 4,
#              'Wind speed': 4.6},
#  'conakry': {'Cloudiness': 75,
#              'Country': 'GN',
#              'Date': '2019-09-21',
#              'Humidity': 83,
#              'Lat': 9.52,
#              'Long': -13.7,
#              'Temperature': 28,
#              'Wind speed': 3.1},
#  'constitucion': {'Cloudiness': 20,
#                   'Country': 'MX',
#                   'Date': '2019-09-21',
#                   'Humidity': 60,
#                   'Lat': 23.99,
#                   'Long': -104.67,
#                   'Temperature': 22.22,
#                   'Wind speed': 1.65},
#  'coquimbo': {'Cloudiness': 0,
#               'Country': 'CL',
#               'Date': '2019-09-21',
#               'Humidity': 63,
#               'Lat': -29.95,
#               'Long': -71.34,
#               'Temperature': 16,
#               'Wind speed': 7.2},
#  'cordenons': {'Cloudiness': 5,
#                'Country': 'IT',
#                'Date': '2019-09-21',
#                'Humidity': 45,
#                'Lat': 45.99,
#                'Long': 12.71,
#                'Temperature': 20,
#                'Wind speed': 1.5},
#  'council bluffs': {'Cloudiness': 90,
#                     'Country': 'US',
#                     'Date': '2019-09-21',
#                     'Humidity': 94,
#                     'Lat': 41.26,
#                     'Long': -95.86,
#                     'Temperature': 26.67,
#                     'Wind speed': 6.7},
#  'craig': {'Cloudiness': 1,
#            'Country': 'US',
#            'Date': '2019-09-21',
#            'Humidity': 37,
#            'Lat': 40.52,
#            'Long': -107.55,
#            'Temperature': 12,
#            'Wind speed': 2.1},
#  'cumberland': {'Cloudiness': 1,
#                 'Country': 'US',
#                 'Date': '2019-09-21',
#                 'Humidity': 54,
#                 'Lat': 41.97,
#                 'Long': -71.43,
#                 'Temperature': 29.44,
#                 'Wind speed': 1.5},
#  'cururupu': {'Cloudiness': 59,
#               'Country': 'BR',
#               'Date': '2019-09-21',
#               'Humidity': 50,
#               'Lat': -1.82,
#               'Long': -44.87,
#               'Temperature': 31.7,
#               'Wind speed': 3.1},
#  'dali': {'Cloudiness': 0,
#           'Country': 'CN',
#           'Date': '2019-09-21',
#           'Humidity': 62,
#           'Lat': 34.79,
#           'Long': 109.94,
#           'Temperature': 17.2,
#           'Wind speed': 0.39},
#  'daru': {'Cloudiness': 99,
#           'Country': 'PG',
#           'Date': '2019-09-21',
#           'Humidity': 90,
#           'Lat': -9.07,
#           'Long': 143.21,
#           'Temperature': 23.9,
#           'Wind speed': 4.32},
#  'dawei': {'Cloudiness': 87,
#            'Country': 'MM',
#            'Date': '2019-09-21',
#            'Humidity': 87,
#            'Lat': 14.07,
#            'Long': 98.19,
#            'Temperature': 26.1,
#            'Wind speed': 6.28},
#  'diego de almagro': {'Cloudiness': 0,
#                       'Country': 'CL',
#                       'Date': '2019-09-21',
#                       'Humidity': 43,
#                       'Lat': -26.39,
#                       'Long': -70.05,
#                       'Temperature': 19,
#                       'Wind speed': 4.5},
#  'diffa': {'Cloudiness': 20,
#            'Country': 'NE',
#            'Date': '2019-09-21',
#            'Humidity': 12,
#            'Lat': 13.32,
#            'Long': 12.61,
#            'Temperature': 35.2,
#            'Wind speed': 2.85},
#  'dikson': {'Cloudiness': 100,
#             'Country': 'RU',
#             'Date': '2019-09-21',
#             'Humidity': 96,
#             'Lat': 73.51,
#             'Long': 80.55,
#             'Temperature': 2.5,
#             'Wind speed': 9.63},
#  'dingle': {'Cloudiness': 100,
#             'Country': 'PH',
#             'Date': '2019-09-21',
#             'Humidity': 84,
#             'Lat': 11,
#             'Long': 122.67,
#             'Temperature': 23.2,
#             'Wind speed': 1.51},
#  'dinkelsbuhl': {'Cloudiness': 1,
#                  'Country': 'DE',
#                  'Date': '2019-09-21',
#                  'Humidity': 37,
#                  'Lat': 49.07,
#                  'Long': 10.32,
#                  'Temperature': 21,
#                  'Wind speed': 3.6},
#  'dire': {'Cloudiness': 100,
#           'Country': 'ET',
#           'Date': '2019-09-21',
#           'Humidity': 90,
#           'Lat': 9.18,
#           'Long': 38.92,
#           'Temperature': 14,
#           'Wind speed': 1.53},
#  'doha': {'Cloudiness': 0,
#           'Country': 'QA',
#           'Date': '2019-09-21',
#           'Humidity': 59,
#           'Lat': 25.29,
#           'Long': 51.53,
#           'Temperature': 34,
#           'Wind speed': 3.1},
#  'dombarovskiy': {'Cloudiness': 100,
#                   'Country': 'RU',
#                   'Date': '2019-09-21',
#                   'Humidity': 94,
#                   'Lat': 50.76,
#                   'Long': 59.54,
#                   'Temperature': 10.1,
#                   'Wind speed': 2.66},
#  'domingos martins': {'Cloudiness': 0,
#                       'Country': 'BR',
#                       'Date': '2019-09-21',
#                       'Humidity': 65,
#                       'Lat': -20.36,
#                       'Long': -40.66,
#                       'Temperature': 28,
#                       'Wind speed': 8.2},
#  'dwarka': {'Cloudiness': 40,
#             'Country': 'IN',
#             'Date': '2019-09-21',
#             'Humidity': 94,
#             'Lat': 28.58,
#             'Long': 77.04,
#             'Temperature': 32.22,
#             'Wind speed': 2.1},
#  'east london': {'Cloudiness': 75,
#                  'Country': 'ZA',
#                  'Date': '2019-09-21',
#                  'Humidity': 82,
#                  'Lat': -33.02,
#                  'Long': 27.91,
#                  'Temperature': 17,
#                  'Wind speed': 4.1},
#  'eggenfelden': {'Cloudiness': 0,
#                  'Country': 'DE',
#                  'Date': '2019-09-21',
#                  'Humidity': 67,
#                  'Lat': 48.4,
#                  'Long': 12.76,
#                  'Temperature': 17,
#                  'Wind speed': 2.6},
#  'ekibastuz': {'Cloudiness': 64,
#                'Country': 'KZ',
#                'Date': '2019-09-21',
#                'Humidity': 44,
#                'Lat': 51.72,
#                'Long': 75.32,
#                'Temperature': 14.2,
#                'Wind speed': 6.5},
#  'emerald': {'Cloudiness': 0,
#              'Country': 'AU',
#              'Date': '2019-09-21',
#              'Humidity': 77,
#              'Lat': -23.53,
#              'Long': 148.16,
#              'Temperature': 16,
#              'Wind speed': 1},
#  'enniskerry': {'Cloudiness': 90,
#                 'Country': 'IE',
#                 'Date': '2019-09-21',
#                 'Humidity': 82,
#                 'Lat': 53.19,
#                 'Long': -6.17,
#                 'Temperature': 18,
#                 'Wind speed': 3.1},
#  'esmeraldas': {'Cloudiness': 0,
#                 'Country': 'BR',
#                 'Date': '2019-09-21',
#                 'Humidity': 26,
#                 'Lat': -19.76,
#                 'Long': -44.31,
#                 'Temperature': 35,
#                 'Wind speed': 2.1},
#  'esperance': {'Cloudiness': 75,
#                'Country': 'AU',
#                'Date': '2019-09-21',
#                'Humidity': 93,
#                'Lat': -33.86,
#                'Long': 121.89,
#                'Temperature': 7,
#                'Wind speed': 2.1},
#  'evensk': {'Cloudiness': 49,
#             'Country': 'RU',
#             'Date': '2019-09-21',
#             'Humidity': 69,
#             'Lat': 61.92,
#             'Long': 159.24,
#             'Temperature': 0.4,
#             'Wind speed': 1.16},
#  'faanui': {'Cloudiness': 52,
#             'Country': 'PF',
#             'Date': '2019-09-21',
#             'Humidity': 83,
#             'Lat': -16.48,
#             'Long': -151.75,
#             'Temperature': 26.6,
#             'Wind speed': 7.1},
#  'fairbanks': {'Cloudiness': 90,
#                'Country': 'US',
#                'Date': '2019-09-21',
#                'Humidity': 93,
#                'Lat': 64.84,
#                'Long': -147.72,
#                'Temperature': 4,
#                'Wind speed': 4.6},
#  'faya': {'Cloudiness': 0,
#           'Country': 'SA',
#           'Date': '2019-09-21',
#           'Humidity': 13,
#           'Lat': 18.39,
#           'Long': 42.45,
#           'Temperature': 24,
#           'Wind speed': 5.1},
#  'flinders': {'Cloudiness': 57,
#               'Country': 'AU',
#               'Date': '2019-09-21',
#               'Humidity': 63,
#               'Lat': -34.58,
#               'Long': 150.85,
#               'Temperature': 18.89,
#               'Wind speed': 2.1},
#  'forestville': {'Cloudiness': 20,
#                  'Country': 'CA',
#                  'Date': '2019-09-21',
#                  'Humidity': 54,
#                  'Lat': 48.74,
#                  'Long': -69.09,
#                  'Temperature': 14,
#                  'Wind speed': 1},
#  'fort nelson': {'Cloudiness': 75,
#                  'Country': 'CA',
#                  'Date': '2019-09-21',
#                  'Humidity': 87,
#                  'Lat': 58.81,
#                  'Long': -122.69,
#                  'Temperature': 10,
#                  'Wind speed': 1},
#  'fortuna': {'Cloudiness': 20,
#              'Country': 'US',
#              'Date': '2019-09-21',
#              'Humidity': 82,
#              'Lat': 40.6,
#              'Long': -124.16,
#              'Temperature': 19.44,
#              'Wind speed': 2.1},
#  'galveston': {'Cloudiness': 40,
#                'Country': 'US',
#                'Date': '2019-09-21',
#                'Humidity': 54,
#                'Lat': 40.58,
#                'Long': -86.19,
#                'Temperature': 31.11,
#                'Wind speed': 3.6},
#  'gao': {'Cloudiness': 2,
#          'Country': 'ML',
#          'Date': '2019-09-21',
#          'Humidity': 14,
#          'Lat': 16.28,
#          'Long': -0.04,
#          'Temperature': 38.6,
#          'Wind speed': 2.89},
#  'general pico': {'Cloudiness': 0,
#                   'Country': 'AR',
#                   'Date': '2019-09-21',
#                   'Humidity': 19,
#                   'Lat': -35.66,
#                   'Long': -63.75,
#                   'Temperature': 21.7,
#                   'Wind speed': 5.8},
#  'george town': {'Cloudiness': 75,
#                  'Country': 'MY',
#                  'Date': '2019-09-21',
#                  'Humidity': 88,
#                  'Lat': 5.42,
#                  'Long': 100.33,
#                  'Temperature': 29,
#                  'Wind speed': 1.5},
#  'georgetown': {'Cloudiness': 75,
#                 'Country': 'GY',
#                 'Date': '2019-09-21',
#                 'Humidity': 70,
#                 'Lat': 6.8,
#                 'Long': -58.16,
#                 'Temperature': 31,
#                 'Wind speed': 7.2},
#  'geraldton': {'Cloudiness': 90,
#                'Country': 'CA',
#                'Date': '2019-09-21',
#                'Humidity': 88,
#                'Lat': 49.72,
#                'Long': -86.95,
#                'Temperature': 19,
#                'Wind speed': 3.6},
#  'gewane': {'Cloudiness': 61,
#             'Country': 'ET',
#             'Date': '2019-09-21',
#             'Humidity': 47,
#             'Lat': 10.16,
#             'Long': 40.66,
#             'Temperature': 29.3,
#             'Wind speed': 4.86},
#  'gigmoto': {'Cloudiness': 100,
#              'Country': 'PH',
#              'Date': '2019-09-21',
#              'Humidity': 76,
#              'Lat': 13.78,
#              'Long': 124.39,
#              'Temperature': 27.7,
#              'Wind speed': 5.72},
#  'ginda': {'Cloudiness': 0,
#            'Country': 'IN',
#            'Date': '2019-09-21',
#            'Humidity': 87,
#            'Lat': 30.69,
#            'Long': 78.49,
#            'Temperature': 12.6,
#            'Wind speed': 1.71},
#  'gizo': {'Cloudiness': 20,
#           'Country': 'IL',
#           'Date': '2019-09-21',
#           'Humidity': 65,
#           'Lat': 31.8,
#           'Long': 34.94,
#           'Temperature': 26.11,
#           'Wind speed': 2.1},
#  'goderich': {'Cloudiness': 1,
#               'Country': 'CA',
#               'Date': '2019-09-21',
#               'Humidity': 62,
#               'Lat': 43.74,
#               'Long': -81.71,
#               'Temperature': 29.44,
#               'Wind speed': 4.02},
#  'gondar': {'Cloudiness': 75,
#             'Country': 'PT',
#             'Date': '2019-09-21',
#             'Humidity': 88,
#             'Lat': 41.82,
#             'Long': -8.78,
#             'Temperature': 18.89,
#             'Wind speed': 5.7},
#  'grand island': {'Cloudiness': 90,
#                   'Country': 'US',
#                   'Date': '2019-09-21',
#                   'Humidity': 61,
#                   'Lat': 40.92,
#                   'Long': -98.34,
#                   'Temperature': 27.22,
#                   'Wind speed': 3.6},
#  'gravdal': {'Cloudiness': 0,
#              'Country': 'NO',
#              'Date': '2019-09-21',
#              'Humidity': 87,
#              'Lat': 59.79,
#              'Long': 5.78,
#              'Temperature': 16,
#              'Wind speed': 2.6},
#  'grindavik': {'Cloudiness': 75,
#                'Country': 'IS',
#                'Date': '2019-09-21',
#                'Humidity': 87,
#                'Lat': 63.84,
#                'Long': -22.43,
#                'Temperature': 14,
#                'Wind speed': 7.7},
#  'guerrero negro': {'Cloudiness': 0,
#                     'Country': 'MX',
#                     'Date': '2019-09-21',
#                     'Humidity': 84,
#                     'Lat': 27.97,
#                     'Long': -114.04,
#                     'Temperature': 20.2,
#                     'Wind speed': 5.43},
#  'guican': {'Cloudiness': 100,
#             'Country': 'CO',
#             'Date': '2019-09-21',
#             'Humidity': 94,
#             'Lat': 6.46,
#             'Long': -72.41,
#             'Temperature': 12,
#             'Wind speed': 0.93},
#  'haines junction': {'Cloudiness': 79,
#                      'Country': 'CA',
#                      'Date': '2019-09-21',
#                      'Humidity': 84,
#                      'Lat': 60.75,
#                      'Long': -137.51,
#                      'Temperature': 5.9,
#                      'Wind speed': 3.82},
#  'half moon bay': {'Cloudiness': 1,
#                    'Country': 'US',
#                    'Date': '2019-09-21',
#                    'Humidity': 60,
#                    'Lat': 37.46,
#                    'Long': -122.43,
#                    'Temperature': 26.67,
#                    'Wind speed': 3.12},
#  'halifax': {'Cloudiness': 20,
#              'Country': 'CA',
#              'Date': '2019-09-21',
#              'Humidity': 42,
#              'Lat': 44.65,
#              'Long': -63.58,
#              'Temperature': 22.22,
#              'Wind speed': 9.8},
#  'hambantota': {'Cloudiness': 66,
#                 'Country': 'LK',
#                 'Date': '2019-09-21',
#                 'Humidity': 81,
#                 'Lat': 6.12,
#                 'Long': 81.12,
#                 'Temperature': 27.7,
#                 'Wind speed': 6.03},
#  'harper': {'Cloudiness': 40,
#             'Country': 'US',
#             'Date': '2019-09-21',
#             'Humidity': 49,
#             'Lat': 30.3,
#             'Long': -99.24,
#             'Temperature': 32,
#             'Wind speed': 8.2},
#  'hasaki': {'Cloudiness': 75,
#             'Country': 'JP',
#             'Date': '2019-09-21',
#             'Humidity': 88,
#             'Lat': 35.73,
#             'Long': 140.83,
#             'Temperature': 19,
#             'Wind speed': 3.6},
#  'havelock': {'Cloudiness': 1,
#               'Country': 'US',
#               'Date': '2019-09-21',
#               'Humidity': 39,
#               'Lat': 34.88,
#               'Long': -76.9,
#               'Temperature': 28.33,
#               'Wind speed': 3.6},
#  'hays': {'Cloudiness': 40,
#           'Country': 'US',
#           'Date': '2019-09-21',
#           'Humidity': 58,
#           'Lat': 38.88,
#           'Long': -99.33,
#           'Temperature': 31.11,
#           'Wind speed': 9.8},
#  'hegang': {'Cloudiness': 39,
#             'Country': 'CN',
#             'Date': '2019-09-21',
#             'Humidity': 88,
#             'Lat': 47.34,
#             'Long': 130.28,
#             'Temperature': 5,
#             'Wind speed': 2.37},
#  'hermanus': {'Cloudiness': 81,
#               'Country': 'ZA',
#               'Date': '2019-09-21',
#               'Humidity': 98,
#               'Lat': -34.42,
#               'Long': 19.24,
#               'Temperature': 13.89,
#               'Wind speed': 0.89},
#  'hilo': {'Cloudiness': 40,
#           'Country': 'US',
#           'Date': '2019-09-21',
#           'Humidity': 73,
#           'Lat': 19.71,
#           'Long': -155.08,
#           'Temperature': 24,
#           'Wind speed': 2.6},
#  'hirado': {'Cloudiness': 75,
#             'Country': 'JP',
#             'Date': '2019-09-21',
#             'Humidity': 94,
#             'Lat': 33.32,
#             'Long': 129.49,
#             'Temperature': 25.56,
#             'Wind speed': 9.3},
#  'hirara': {'Cloudiness': 93,
#             'Country': 'JP',
#             'Date': '2019-09-21',
#             'Humidity': 80,
#             'Lat': 24.8,
#             'Long': 125.28,
#             'Temperature': 26,
#             'Wind speed': 12.02},
#  'hit': {'Cloudiness': 0,
#          'Country': 'IQ',
#          'Date': '2019-09-21',
#          'Humidity': 17,
#          'Lat': 33.64,
#          'Long': 42.83,
#          'Temperature': 30.1,
#          'Wind speed': 4.3},
#  'hithadhoo': {'Cloudiness': 100,
#                'Country': 'MV',
#                'Date': '2019-09-21',
#                'Humidity': 77,
#                'Lat': -0.6,
#                'Long': 73.08,
#                'Temperature': 25.3,
#                'Wind speed': 3.99},
#  'hobart': {'Cloudiness': 66,
#             'Country': 'AU',
#             'Date': '2019-09-21',
#             'Humidity': 88,
#             'Lat': -42.88,
#             'Long': 147.33,
#             'Temperature': 9,
#             'Wind speed': 8.2},
#  'hobyo': {'Cloudiness': 58,
#            'Country': 'SO',
#            'Date': '2019-09-21',
#            'Humidity': 80,
#            'Lat': 5.35,
#            'Long': 48.53,
#            'Temperature': 24.7,
#            'Wind speed': 11.7},
#  'hofn': {'Cloudiness': 100,
#           'Country': 'IS',
#           'Date': '2019-09-21',
#           'Humidity': 98,
#           'Lat': 64.25,
#           'Long': -15.21,
#           'Temperature': 3.9,
#           'Wind speed': 0.76},
#  'honiara': {'Cloudiness': 75,
#              'Country': 'SB',
#              'Date': '2019-09-21',
#              'Humidity': 94,
#              'Lat': -9.43,
#              'Long': 159.96,
#              'Temperature': 23,
#              'Wind speed': 1},
#  'huarmey': {'Cloudiness': 82,
#              'Country': 'PE',
#              'Date': '2019-09-21',
#              'Humidity': 91,
#              'Lat': -10.07,
#              'Long': -78.15,
#              'Temperature': 16,
#              'Wind speed': 4.76},
#  'hueyotlipan': {'Cloudiness': 5,
#                  'Country': 'MX',
#                  'Date': '2019-09-21',
#                  'Humidity': 33,
#                  'Lat': 19.47,
#                  'Long': -98.35,
#                  'Temperature': 22,
#                  'Wind speed': 2.6},
#  'husavik': {'Cloudiness': 100,
#              'Country': 'CA',
#              'Date': '2019-09-21',
#              'Humidity': 98,
#              'Lat': 50.56,
#              'Long': -96.99,
#              'Temperature': 18.33,
#              'Wind speed': 4.64},
#  'igunga': {'Cloudiness': 64,
#             'Country': 'TZ',
#             'Date': '2019-09-21',
#             'Humidity': 37,
#             'Lat': -4.28,
#             'Long': 33.88,
#             'Temperature': 24.7,
#             'Wind speed': 3.7},
#  'ihosy': {'Cloudiness': 17,
#            'Country': 'MG',
#            'Date': '2019-09-21',
#            'Humidity': 86,
#            'Lat': -22.4,
#            'Long': 46.13,
#            'Temperature': 15,
#            'Wind speed': 7.34},
#  'ilulissat': {'Cloudiness': 75,
#                'Country': 'GL',
#                'Date': '2019-09-21',
#                'Humidity': 52,
#                'Lat': 69.22,
#                'Long': -51.1,
#                'Temperature': 8,
#                'Wind speed': 6.7},
#  'inhambane': {'Cloudiness': 0,
#                'Country': 'MZ',
#                'Date': '2019-09-21',
#                'Humidity': 85,
#                'Lat': -23.87,
#                'Long': 35.38,
#                'Temperature': 19.2,
#                'Wind speed': 3.81},
#  'ipixuna': {'Cloudiness': 40,
#              'Country': 'BR',
#              'Date': '2019-09-21',
#              'Humidity': 62,
#              'Lat': -1.76,
#              'Long': -48.8,
#              'Temperature': 31,
#              'Wind speed': 3.6},
#  'iqaluit': {'Cloudiness': 75,
#              'Country': 'CA',
#              'Date': '2019-09-21',
#              'Humidity': 74,
#              'Lat': 63.75,
#              'Long': -68.52,
#              'Temperature': 6,
#              'Wind speed': 12.9},
#  'isangel': {'Cloudiness': 92,
# ...
#                'Temperature': -1.21,
#                'Wind speed': 1.58},
#  'tiznit': {'Cloudiness': 17,
#             'Country': 'MA',
#             'Date': '2019-09-21',
#             'Humidity': 89,
#             'Lat': 29.7,
#             'Long': -9.73,
#             'Temperature': 20.5,
#             'Wind speed': 3.68},
#  'togur': {'Cloudiness': 100,
#            'Country': 'RU',
#            'Date': '2019-09-21',
#            'Humidity': 68,
#            'Lat': 58.36,
#            'Long': 82.83,
#            'Temperature': 5.9,
#            'Wind speed': 2.55},
#  'torbay': {'Cloudiness': 90,
#             'Country': 'CA',
#             'Date': '2019-09-21',
#             'Humidity': 93,
#             'Lat': 47.66,
#             'Long': -52.73,
#             'Temperature': 9.44,
#             'Wind speed': 12.3},
#  'touros': {'Cloudiness': 40,
#             'Country': 'BR',
#             'Date': '2019-09-21',
#             'Humidity': 78,
#             'Lat': -5.2,
#             'Long': -35.46,
#             'Temperature': 26,
#             'Wind speed': 3.6},
#  'trincomalee': {'Cloudiness': 100,
#                  'Country': 'LK',
#                  'Date': '2019-09-21',
#                  'Humidity': 88,
#                  'Lat': 8.58,
#                  'Long': 81.23,
#                  'Temperature': 25.2,
#                  'Wind speed': 1.54},
#  'trinidad': {'Cloudiness': 75,
#               'Country': 'BO',
#               'Date': '2019-09-21',
#               'Humidity': 50,
#               'Lat': -14.83,
#               'Long': -64.9,
#               'Temperature': 26,
#               'Wind speed': 2.1},
#  'tual': {'Cloudiness': 18,
#           'Country': 'ID',
#           'Date': '2019-09-21',
#           'Humidity': 85,
#           'Lat': -5.67,
#           'Long': 132.75,
#           'Temperature': 24.8,
#           'Wind speed': 5.62},
#  'tuatapere': {'Cloudiness': 12,
#                'Country': 'NZ',
#                'Date': '2019-09-21',
#                'Humidity': 95,
#                'Lat': -46.13,
#                'Long': 167.69,
#                'Temperature': 3.89,
#                'Wind speed': 0.89},
#  'tuktoyaktuk': {'Cloudiness': 75,
#                  'Country': 'CA',
#                  'Date': '2019-09-21',
#                  'Humidity': 86,
#                  'Lat': 69.44,
#                  'Long': -133.03,
#                  'Temperature': 5,
#                  'Wind speed': 7.7},
#  'tura': {'Cloudiness': 100,
#           'Country': 'RU',
#           'Date': '2019-09-21',
#           'Humidity': 75,
#           'Lat': 64.27,
#           'Long': 100.22,
#           'Temperature': 3.7,
#           'Wind speed': 9.13},
#  'tynda': {'Cloudiness': 17,
#            'Country': 'RU',
#            'Date': '2019-09-21',
#            'Humidity': 95,
#            'Lat': 55.15,
#            'Long': 124.74,
#            'Temperature': 0.2,
#            'Wind speed': 0.82},
#  'ulladulla': {'Cloudiness': 59,
#                'Country': 'AU',
#                'Date': '2019-09-21',
#                'Humidity': 63,
#                'Lat': -35.36,
#                'Long': 150.48,
#                'Temperature': 16,
#                'Wind speed': 2.1},
#  'ullapool': {'Cloudiness': 0,
#               'Country': 'GB',
#               'Date': '2019-09-21',
#               'Humidity': 66,
#               'Lat': 57.9,
#               'Long': -5.16,
#               'Temperature': 17.2,
#               'Wind speed': 4},
#  'umba': {'Cloudiness': 95,
#           'Country': 'RU',
#           'Date': '2019-09-21',
#           'Humidity': 88,
#           'Lat': 66.69,
#           'Long': 34.34,
#           'Temperature': 1.3,
#           'Wind speed': 2.65},
#  'umm lajj': {'Cloudiness': 0,
#               'Country': 'SA',
#               'Date': '2019-09-21',
#               'Humidity': 74,
#               'Lat': 25.02,
#               'Long': 37.27,
#               'Temperature': 28.9,
#               'Wind speed': 5.91},
#  'upernavik': {'Cloudiness': 100,
#                'Country': 'GL',
#                'Date': '2019-09-21',
#                'Humidity': 68,
#                'Lat': 72.79,
#                'Long': -56.15,
#                'Temperature': 3.5,
#                'Wind speed': 5.93},
#  'ushuaia': {'Cloudiness': 75,
#              'Country': 'AR',
#              'Date': '2019-09-21',
#              'Humidity': 74,
#              'Lat': -54.81,
#              'Long': -68.31,
#              'Temperature': 1,
#              'Wind speed': 12.9},
#  'ust-kuyga': {'Cloudiness': 0,
#                'Country': 'RU',
#                'Date': '2019-09-21',
#                'Humidity': 88,
#                'Lat': 70,
#                'Long': 135.55,
#                'Temperature': -1.21,
#                'Wind speed': 2.44},
#  'ust-nera': {'Cloudiness': 92,
#               'Country': 'RU',
#               'Date': '2019-09-21',
#               'Humidity': 84,
#               'Lat': 64.57,
#               'Long': 143.24,
#               'Temperature': -0.71,
#               'Wind speed': 0.97},
#  'vaini': {'Cloudiness': 12,
#            'Country': 'IN',
#            'Date': '2019-09-21',
#            'Humidity': 95,
#            'Lat': 15.34,
#            'Long': 74.49,
#            'Temperature': 24.3,
#            'Wind speed': 1.13},
#  'valdivia': {'Cloudiness': 75,
#               'Country': 'CL',
#               'Date': '2019-09-21',
#               'Humidity': 66,
#               'Lat': -39.81,
#               'Long': -73.25,
#               'Temperature': 13,
#               'Wind speed': 2.1},
#  'vanavara': {'Cloudiness': 32,
#               'Country': 'RU',
#               'Date': '2019-09-21',
#               'Humidity': 82,
#               'Lat': 60.35,
#               'Long': 102.28,
#               'Temperature': 5.4,
#               'Wind speed': 3.76},
#  'vanimo': {'Cloudiness': 90,
#             'Country': 'PG',
#             'Date': '2019-09-21',
#             'Humidity': 75,
#             'Lat': -2.67,
#             'Long': 141.3,
#             'Temperature': 26.5,
#             'Wind speed': 3.99},
#  'vao': {'Cloudiness': 100,
#          'Country': 'EE',
#          'Date': '2019-09-21',
#          'Humidity': 86,
#          'Lat': 59.1,
#          'Long': 26.19,
#          'Temperature': 9.8,
#          'Wind speed': 5.37},
#  'vardo': {'Cloudiness': 1,
#            'Country': 'US',
#            'Date': '2019-09-21',
#            'Humidity': 39,
#            'Lat': 39.62,
#            'Long': -77.74,
#            'Temperature': 31.11,
#            'Wind speed': 3.1},
#  'velyka lepetykha': {'Cloudiness': 45,
#                       'Country': 'UA',
#                       'Date': '2019-09-21',
#                       'Humidity': 50,
#                       'Lat': 47.18,
#                       'Long': 33.94,
#                       'Temperature': 8.4,
#                       'Wind speed': 2.78},
#  'vestmannaeyjar': {'Cloudiness': 90,
#                     'Country': 'IS',
#                     'Date': '2019-09-21',
#                     'Humidity': 100,
#                     'Lat': 63.44,
#                     'Long': -20.27,
#                     'Temperature': 11,
#                     'Wind speed': 12.9},
#  'victoria': {'Cloudiness': 75,
#               'Country': 'BN',
#               'Date': '2019-09-21',
#               'Humidity': 83,
#               'Lat': 5.28,
#               'Long': 115.24,
#               'Temperature': 28,
#               'Wind speed': 2.6},
#  'vigia del fuerte': {'Cloudiness': 100,
#                       'Country': 'CO',
#                       'Date': '2019-09-21',
#                       'Humidity': 75,
#                       'Lat': 6.58,
#                       'Long': -76.89,
#                       'Temperature': 26.7,
#                       'Wind speed': 0.93},
#  'vila': {'Cloudiness': 0,
#           'Country': 'IT',
#           'Date': '2019-09-21',
#           'Humidity': 40,
#           'Lat': 45.18,
#           'Long': 8.4,
#           'Temperature': 20,
#           'Wind speed': 2.1},
#  'vostok': {'Cloudiness': 91,
#             'Country': 'RU',
#             'Date': '2019-09-21',
#             'Humidity': 99,
#             'Lat': 46.45,
#             'Long': 135.83,
#             'Temperature': 6,
#             'Wind speed': 1.83},
#  'vrangel': {'Cloudiness': 46,
#              'Country': 'RU',
#              'Date': '2019-09-21',
#              'Humidity': 85,
#              'Lat': 42.73,
#              'Long': 133.08,
#              'Temperature': 7.8,
#              'Wind speed': 2.22},
#  'waddan': {'Cloudiness': 0,
#             'Country': 'LY',
#             'Date': '2019-09-21',
#             'Humidity': 25,
#             'Lat': 29.16,
#             'Long': 16.14,
#             'Temperature': 30.2,
#             'Wind speed': 4.4},
#  'waingapu': {'Cloudiness': 64,
#               'Country': 'ID',
#               'Date': '2019-09-21',
#               'Humidity': 88,
#               'Lat': -9.65,
#               'Long': 120.26,
#               'Temperature': 19.7,
#               'Wind speed': 2.14},
#  'waipawa': {'Cloudiness': 0,
#              'Country': 'NZ',
#              'Date': '2019-09-21',
#              'Humidity': 97,
#              'Lat': -39.94,
#              'Long': 176.59,
#              'Temperature': 2.5,
#              'Wind speed': 0.76},
#  'walvis bay': {'Cloudiness': 0,
#                 'Country': 'NA',
#                 'Date': '2019-09-21',
#                 'Humidity': 72,
#                 'Lat': -22.95,
#                 'Long': 14.51,
#                 'Temperature': 17,
#                 'Wind speed': 5.1},
#  'wanning': {'Cloudiness': 0,
#              'Country': 'AT',
#              'Date': '2019-09-21',
#              'Humidity': 45,
#              'Lat': 48.64,
#              'Long': 13.53,
#              'Temperature': 19,
#              'Wind speed': 4.6},
#  'warrensburg': {'Cloudiness': 90,
#                  'Country': 'US',
#                  'Date': '2019-09-21',
#                  'Humidity': 73,
#                  'Lat': 38.76,
#                  'Long': -93.74,
#                  'Temperature': 27,
#                  'Wind speed': 7.7},
#  'waverly': {'Cloudiness': 1,
#              'Country': 'US',
#              'Date': '2019-09-21',
#              'Humidity': 42,
#              'Lat': 37.04,
#              'Long': -77.1,
#              'Temperature': 31.11,
#              'Wind speed': 2.6},
#  'weifang': {'Cloudiness': 0,
#              'Country': 'CN',
#              'Date': '2019-09-21',
#              'Humidity': 86,
#              'Lat': 36.71,
#              'Long': 119.16,
#              'Temperature': 17.3,
#              'Wind speed': 2.22},
#  'west odessa': {'Cloudiness': 40,
#                  'Country': 'US',
#                  'Date': '2019-09-21',
#                  'Humidity': 65,
#                  'Lat': 31.84,
#                  'Long': -102.48,
#                  'Temperature': 26,
#                  'Wind speed': 5.7},
#  'westlock': {'Cloudiness': 90,
#               'Country': 'CA',
#               'Date': '2019-09-21',
#               'Humidity': 76,
#               'Lat': 54.15,
#               'Long': -113.85,
#               'Temperature': 12.78,
#               'Wind speed': 2.1},
#  'westport': {'Cloudiness': 1,
#               'Country': 'US',
#               'Date': '2019-09-21',
#               'Humidity': 39,
#               'Lat': 41.14,
#               'Long': -73.36,
#               'Temperature': 28.89,
#               'Wind speed': 0.8},
#  'whangamata': {'Cloudiness': 0,
#                 'Country': 'NZ',
#                 'Date': '2019-09-21',
#                 'Humidity': 85,
#                 'Lat': -37.21,
#                 'Long': 175.87,
#                 'Temperature': 9.44,
#                 'Wind speed': 1.34},
#  'wilmington': {'Cloudiness': 1,
#                 'Country': 'US',
#                 'Date': '2019-09-21',
#                 'Humidity': 32,
#                 'Lat': 39.75,
#                 'Long': -75.55,
#                 'Temperature': 30,
#                 'Wind speed': 1.5},
#  'windsor': {'Cloudiness': 1,
#              'Country': 'US',
#              'Date': '2019-09-21',
#              'Humidity': 62,
#              'Lat': 42.3,
#              'Long': -83.03,
#              'Temperature': 31,
#              'Wind speed': 4.6},
#  'xichang': {'Cloudiness': 99,
#              'Country': 'CN',
#              'Date': '2019-09-21',
#              'Humidity': 78,
#              'Lat': 27.88,
#              'Long': 102.25,
#              'Temperature': 8.1,
#              'Wind speed': 1.4},
#  'xinqing': {'Cloudiness': 58,
#              'Country': 'CN',
#              'Date': '2019-09-21',
#              'Humidity': 88,
#              'Lat': 48.28,
#              'Long': 129.53,
#              'Temperature': 5.8,
#              'Wind speed': 1.64},
#  'yabelo': {'Cloudiness': 82,
#             'Country': 'ET',
#             'Date': '2019-09-21',
#             'Humidity': 54,
#             'Lat': 4.89,
#             'Long': 38.09,
#             'Temperature': 20.9,
#             'Wind speed': 4},
#  'yakeshi': {'Cloudiness': 0,
#              'Country': 'CN',
#              'Date': '2019-09-21',
#              'Humidity': 80,
#              'Lat': 49.28,
#              'Long': 120.73,
#              'Temperature': 6.5,
#              'Wind speed': 1.4},
#  'yakima': {'Cloudiness': 1,
#             'Country': 'US',
#             'Date': '2019-09-21',
#             'Humidity': 59,
#             'Lat': 46.6,
#             'Long': -120.51,
#             'Temperature': 19.44,
#             'Wind speed': 1.51},
#  'yamada': {'Cloudiness': 75,
#             'Country': 'JP',
#             'Date': '2019-09-21',
#             'Humidity': 77,
#             'Lat': 36.58,
#             'Long': 137.08,
#             'Temperature': 21.11,
#             'Wind speed': 3.1},
#  'yar-sale': {'Cloudiness': 0,
#               'Country': 'RU',
#               'Date': '2019-09-21',
#               'Humidity': 68,
#               'Lat': 66.83,
#               'Long': 70.83,
#               'Temperature': 2.4,
#               'Wind speed': 6.51},
#  'yarmouth': {'Cloudiness': 20,
#               'Country': 'CA',
#               'Date': '2019-09-21',
#               'Humidity': 72,
#               'Lat': 43.84,
#               'Long': -66.12,
#               'Temperature': 20,
#               'Wind speed': 5.7},
#  'yatou': {'Cloudiness': 69,
#            'Country': 'CM',
#            'Date': '2019-09-21',
#            'Humidity': 87,
#            'Lat': 3.63,
#            'Long': 9.81,
#            'Temperature': 26.2,
#            'Wind speed': 4.79},
#  'yellowknife': {'Cloudiness': 75,
#                  'Country': 'CA',
#                  'Date': '2019-09-21',
#                  'Humidity': 93,
#                  'Lat': 62.45,
#                  'Long': -114.38,
#                  'Temperature': 9,
#                  'Wind speed': 6.2},
#  'yulara': {'Cloudiness': 0,
#             'Country': 'AU',
#             'Date': '2019-09-21',
#             'Humidity': 31,
#             'Lat': -25.24,
#             'Long': 130.99,
#             'Temperature': 9,
#             'Wind speed': 2.6},
#  'zambezi': {'Cloudiness': 0,
#              'Country': 'ZM',
#              'Date': '2019-09-21',
#              'Humidity': 22,
#              'Lat': -13.55,
#              'Long': 23.12,
#              'Temperature': 25,
#              'Wind speed': 2.03},
#  'zhengjiatun': {'Cloudiness': 0,
#                  'Country': 'CN',
#                  'Date': '2019-09-21',
#                  'Humidity': 77,
#                  'Lat': 43.51,
#                  'Long': 123.51,
#                  'Temperature': 11.3,
#                  'Wind speed': 0.58},
#  'zhezkazgan': {'Cloudiness': 74,
#                 'Country': 'KZ',
#                 'Date': '2019-09-21',
#                 'Humidity': 29,
#                 'Lat': 47.8,
#                 'Long': 67.71,
#                 'Temperature': 21,
#                 'Wind speed': 6.33},
#  'zhicheng': {'Cloudiness': 0,
#               'Country': 'CN',
#               'Date': '2019-09-21',
#               'Humidity': 43,
#               'Lat': 35.04,
#               'Long': 112.59,
#               'Temperature': 19.4,
#               'Wind speed': 1.85},
#  'zhigansk': {'Cloudiness': 100,
#               'Country': 'RU',
#               'Date': '2019-09-21',
#               'Humidity': 94,
#               'Lat': 66.77,
#               'Long': 123.37,
#               'Temperature': 2.1,
#               'Wind speed': 11.9},
#  'zhuhai': {'Cloudiness': 0,
#             'Country': 'CN',
#             'Date': '2019-09-21',
#             'Humidity': 76,
#             'Lat': 40.71,
#             'Long': 112.04,
#             'Temperature': 11,
#             'Wind speed': 1}}

# %%
cities_df = pd.DataFrame.from_dict(city_stats).transpose()
cities_df.head()
# Out:
#           Cloudiness Country        Date Humidity    Lat    Long Temperature  \
# tasiilaq          90      GL  2019-09-21       70  65.61  -37.64           6
# saskylakh        100      RU  2019-09-21       95  71.97  114.09         4.2
# cape town         75      ZA  2019-09-21       82 -33.93   18.42       15.56
# tiksi            100      RU  2019-09-21       89  71.64  128.87         2.2
# luderitz         100      NA  2019-09-21       59 -26.65   15.16          18
#
#           Wind speed
# tasiilaq         6.2
# saskylakh       5.98
# cape town        4.6
# tiksi           3.16
# luderitz         9.3

# %%
cities_df.to_csv("City Weather Data.csv")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(cities_df["Lat"], cities_df["Temperature"])
plt.grid(alpha=.25)
plt.title(f"Latitude vs. Temperature {date}")
plt.ylabel("Temperature (°C)")
plt.xlabel("Latitude")
plt.savefig("Lat_Temp.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(cities_df["Lat"], cities_df["Humidity"])
plt.grid(alpha=.25)
plt.title(f"Latitude vs. Humidity {date}")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.ylim(top=105, bottom=-5)
plt.savefig("Lat_Hum.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(cities_df["Lat"], cities_df["Cloudiness"])
plt.grid(alpha=.25)
plt.title(f"Latitude vs. Cloudiness {date}")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.ylim(top=105, bottom=-5)
plt.savefig("Lat_Cloud.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(cities_df["Lat"], cities_df["Wind speed"])
plt.grid(alpha=.25)
plt.title(f"Latitude vs. Wind speed {date}")
plt.ylabel("Wind speed (m/s)")
plt.xlabel("Latitude")
plt.savefig("Lat_Wind.png")

# %%
plt.scatter(cities_df["Humidity"], cities_df["Cloudiness"])
plt.grid(alpha=.25)
plt.title(f"Bonus Plot: Humidity vs. Cloudiness {date}")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Humidity (%)")
plt.xlim(right=105)
#plt.savefig("Lat_Wind.png")
# Out:
# (-11.30985663082437, 105)
